# %%
import numpy as np
import math

# %%
with open("data.dat","w") as F:
    for T in range(400,700,5):
        for c in np.linspace(0.01,0.99,101):
            F.write("%f %f %f\n" % ((T-400.0)/300.0,c,c*(1-c)+0.001*T*(c*math.log(c)+(1-c)*math.log(1-c))))
